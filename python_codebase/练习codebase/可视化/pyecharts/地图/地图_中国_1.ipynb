# %% [markdown]
# # 地图的使用

# %% [markdown]
# # 导入包

# %%
from pyecharts.charts import Map
import pandas as pd

# %% [markdown]
# # 导入数据并处理

# %%
from pyecharts.charts import Map
from pyecharts import options as opts
import pandas as pd
from pyecharts.globals import ThemeType

data = pd.read_json('./疫情数据全国.json')
print(data)
c = (
    Map(init_opts=opts.InitOpts(theme=ThemeType.WHITE))

        .add(
        series_name='地区/数据',  # 这个是设置那个标签legend 的图例筛选。
        data_pair=data.values,  # 数据项，最好是直接传json
        is_selected=True,  # 是否选中图例
        selected_mode=True,  # 选中模式，表示是否支持多个选中 、 字符串取值可选'single'表示单选，或者'multiple'表示多选。

    )
        # 这个里面是放全局配置的地方
        .set_global_opts(
        title_opts=opts.TitleOpts(title="疫情地图"),  # 这个是设置了标题是标题配置项
        visualmap_opts=opts.VisualMapOpts(  #
            is_show=True,
            min_=50,
            max_=3000,
            range_color=['green', 'yellow', '#7f7522', '#224b8f', 'red'],
            range_text=['疫情严重地', '疫情低概率'],
        ))
        # 这个是设置颜色地方
        # .set_colors()
        # 这个是设置局部，或者系列配置项的地方
        .set_series_opts()
        # 这个方法是生成html文件
#         .render()

)
c.render_notebook()
# Out:
#      城市   累计确诊
# 0    湖北  68311
# 1    台湾  16683
# 2    香港  12471
# 3    广东   3327
# 4    上海   2887
# 5   黑龙江   2026
# 6    云南   1749
# 7    河南   1637
# 8    江苏   1619
# 9    浙江   1504
# 10   河北   1458
# 11   福建   1323
# 12   四川   1282
# 13   湖南   1199
# 14   北京   1195
# 15  内蒙古   1059
# 16   山东   1023
# 17   安徽   1008
# 18   新疆    981
# 19   江西    959
# 20   辽宁    786
# 21   陕西    712
# 22   重庆    610
# 23   吉林    585
# 24   天津    535
# 25   广西    439
# 26   甘肃    344
# 27   山西    265
# 28   海南    190
# 29   贵州    159
# 30   宁夏    122
# 31   澳门     77
# 32   青海     30
# 33   西藏      1
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="d9954e2c87a14caaa16152faf8acdcf5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_d9954e2c87a14caaa16152faf8acdcf5 = echarts.init(
#                     document.getElementById('d9954e2c87a14caaa16152faf8acdcf5'), 'white', {renderer: 'canvas'});
#                 var option_d9954e2c87a14caaa16152faf8acdcf5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5730\u533a/\u6570\u636e",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 68311
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 16683
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 12471
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 3327
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 2887
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 2026
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 1749
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 1637
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 1619
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 1504
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 1458
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 1323
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 1282
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 1199
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 1195
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 1059
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 1023
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 1008
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 981
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 959
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 786
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 712
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 610
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 585
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 535
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 439
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 344
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 265
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 190
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 159
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 122
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": true,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {},
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5730\u533a/\u6570\u636e"
#             ],
#             "selected": {
#                 "\u5730\u533a/\u6570\u636e": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u75ab\u60c5\u5730\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 50,
#         "max": 3000,
#         "text": [
#             "\u75ab\u60c5\u4e25\u91cd\u5730",
#             "\u75ab\u60c5\u4f4e\u6982\u7387"
#         ],
#         "inRange": {
#             "color": [
#                 "green",
#                 "yellow",
#                 "#7f7522",
#                 "#224b8f",
#                 "red"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_d9954e2c87a14caaa16152faf8acdcf5.setOption(option_d9954e2c87a14caaa16152faf8acdcf5);
#         });
#     </script>
